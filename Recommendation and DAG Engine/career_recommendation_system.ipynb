# %% [markdown]
# # Rule-Based Career Decision System with DAG-Based Learning Path
# This notebook implements the Rule-Based Decision Engine and the DAG-based learning path generator (cosine similarity is not part of this module). MongoDB and Flask sections are included but disabled by default — toggle the flags below to enable them on the deployment machine.

# %% [markdown]
# ## 1. Import Libraries and Setup Environment
# Import required Python libraries: pandas, numpy, networkx, json.

# %%
# %pip install google-generativeai
# %pip install pandas numpy networkx
import os
import sys
import json
import urllib.request
import urllib.error
from typing import Any, Dict, Optional

os.environ["GOOGLE_GENERATIVE_AI_API_KEY"] = os.environ.get("GEMINI_API_KEY", "")
print(os.environ.get("GOOGLE_GENERATIVE_AI_API_KEY", "NOT_SET"))

print(sys.executable)

import google.generativeai as genai
print("import ok")

import re
from typing import List
from dataclasses import dataclass, field

import pandas as pd
import numpy as np
import networkx as nx


def load_skill_curriculum(api_url: Optional[str] = None, fallback_path: str = "skill_curriculum.json") -> Dict[str, Any]:
    """Load the skill curriculum from an API when available, otherwise fall back to a local JSON file."""
    api_url = api_url or os.environ.get("SKILL_CURRICULUM_API_URL") or os.environ.get("CURRICULUM_API_URL")
    fallback_path = os.environ.get("SKILL_CURRICULUM_JSON_PATH", fallback_path)

    if api_url:
        try:
            request = urllib.request.Request(api_url, headers={"Accept": "application/json"})
            with urllib.request.urlopen(request, timeout=15) as response:
                payload = json.load(response)

            if isinstance(payload, dict):
                if "skills" in payload:
                    print(f"Loaded skill curriculum from API: {api_url}")
                    return payload
                if "curriculum" in payload:
                    print(f"Loaded skill curriculum from API: {api_url}")
                    return payload["curriculum"]
                if "data" in payload and isinstance(payload["data"], dict):
                    print(f"Loaded skill curriculum from API: {api_url}")
                    return payload["data"]
            elif isinstance(payload, list):
                print(f"Loaded skill curriculum from API: {api_url}")
                return {"skills": payload}
        except Exception as exc:
            print(f"API curriculum load failed: {exc}")

    if os.path.exists(fallback_path):
        with open(fallback_path, encoding="utf-8") as handle:
            payload = json.load(handle)
        print(f"Loaded skill curriculum from local file: {fallback_path}")
        return payload

    raise FileNotFoundError(f"Could not load skill curriculum from API or fallback path: {fallback_path}")


skill_curriculum = load_skill_curriculum()
curriculum_skills = skill_curriculum.get("skills", skill_curriculum.get("curriculum", {}))
print(f"Loaded {len(curriculum_skills)} skill entries from the curriculum source")


google_api_key = os.environ.get("GOOGLE_GENERATIVE_AI_API_KEY")
if google_api_key:
    genai.configure(api_key=google_api_key)
    print("Google Generative AI configured successfully")
else:
    print("GOOGLE_GENERATIVE_AI_API_KEY not set - skipping Google Generative AI configuration")

print("Libraries imported successfully")
# Out:
# Requirement already satisfied: google-generativeai in .\.venv\Lib\site-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in .\.venv\Lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in .\.venv\Lib\site-packages (from google-generativeai) (2.32.0)
# Requirement already satisfied: google-api-python-client in .\.venv\Lib\site-packages (from google-generativeai) (2.198.0)
# Requirement already satisfied: google-auth>=2.15.0 in .\.venv\Lib\site-packages (from google-generativeai) (2.56.0)
# Requirement already satisfied: protobuf in .\.venv\Lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in .\.venv\Lib\site-packages (from google-generativeai) (2.13.4)
# Requirement already satisfied: tqdm in .\.venv\Lib\site-packages (from google-generativeai) (4.68.4)
# Requirement already satisfied: typing-extensions in .\.venv\Lib\site-packages (from google-generativeai) (4.16.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in .\.venv\Lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.28.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in .\.venv\Lib\site-packages (from google-api-core->google-generativeai) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in .\.venv\Lib\site-packages (from google-api-core->google-generativeai) (2.34.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in .\.venv\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.82.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in .\.venv\Lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\.venv\Lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in .\.venv\Lib\site-packages (from google-auth>=2.15.0->google-generativeai) (49.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\.venv\Lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (2026.6.17)
# Requirement already satisfied: cffi>=2.0.0 in .\.venv\Lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.1.0)
# Requirement already satisfied: pycparser in .\.venv\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in .\.venv\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in .\.venv\Lib\site-packages (from google-api-python-client->google-generativeai) (0.32.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in .\.venv\Lib\site-packages (from google-api-python-client->google-generativeai) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in .\.venv\Lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in .\.venv\Lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.venv\Lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\.venv\Lib\site-packages (from pydantic->google-generativeai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.venv\Lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in .\.venv\Lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in .\.venv\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in .\.venv\Lib\site-packages (2.5.1)
# Requirement already satisfied: networkx in .\.venv\Lib\site-packages (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\.venv\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# AQ.Ab8RN6LjyGN7LE9vmFHM4uH_k1bQoF_Mu8qML6tfs45QSewPYw
# c:\ProjectsVScode\Capstone\.venv\Scripts\python.exe
# import ok
# API curriculum load failed: <urlopen error [WinError 10061] No connection could be made because the target machine actively refused it>
# Loaded skill curriculum from local file: skill_curriculum.json
# Loaded 28 skill entries from the curriculum source
# Google Generative AI configured successfully
# Libraries imported successfully

# %%
# Use the local curriculum API endpoint that serves the merged curriculum JSON.
API_URL = "http://127.0.0.1:8000/curriculum"
os.environ["SKILL_CURRICULUM_API_URL"] = API_URL
print("Using curriculum API URL:", API_URL)
# Out:
# Using curriculum API URL: http://127.0.0.1:8000/curriculum

# %%
# Config flags - set to True on the machine where MongoDB / Flask are set up
USE_MONGODB = False
RUN_FLASK_APP = False

DATA_PATH = "C:\\ProjectsVScode\\Capstone\\jobs_dataset_skills_final.csv"
MONGO_URI = "mongodb://localhost:27017/"
MONGO_DB_NAME = "career_recommendation"

print("Config loaded")
# Out:
# Config loaded

# %% [markdown]
# ## 2. Text Normalization and Skill Standardization
# Clean and standardize skill text before matching.

# %%
def normalize_text(text: Any) -> str:
    if text is None or (isinstance(text, float) and np.isnan(text)):
        return ""
    text = str(text).lower()
    text = re.sub(r"[^a-z0-9\s\-]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text


def parse_skill_list(raw: Any) -> List[str]:
    if raw is None or (isinstance(raw, float) and pd.isna(raw)):
        return []
    parts = [normalize_text(p) for p in str(raw).split(",")]
    return sorted({p for p in parts if p})

print(normalize_text("  Machine-Learning, TensorFlow!! "))
print(parse_skill_list("Python, SQL, Data Visualization, python"))
# Out:
# machine-learning tensorflow
# ['data visualization', 'python', 'sql']

# %% [markdown]
# ## 3. Load and Inspect Job Dataset
# Load job data from CSV. Falls back to a small sample dataset if the CSV isn't found.

# %%
def load_job_dataset(csv_path: str) -> pd.DataFrame:
    if os.path.exists(csv_path):
        df = pd.read_csv(csv_path)
        print(f"Loaded {len(df)} job postings from '{csv_path}'")
    else:
        print(f"'{csv_path}' not found - using built-in sample dataset")
        df = pd.DataFrame([
            {"job_title": "Backend Developer I", "role_category": "backend_developer",
             "skills_str": "python, sql, docker, aws"},
            {"job_title": "Backend Developer II", "role_category": "backend_developer",
             "skills_str": "python, sql, docker, aws, kubernetes"},
            {"job_title": "Backend Developer III", "role_category": "backend_developer",
             "skills_str": "python, sql, aws"},
            {"job_title": "Data Analyst I", "role_category": "data_analyst",
             "skills_str": "python, sql, excel, statistics, tableau"},
            {"job_title": "Data Analyst II", "role_category": "data_analyst",
             "skills_str": "python, sql, excel, power bi"},
            {"job_title": "Data Analyst III", "role_category": "data_analyst",
             "skills_str": "sql, excel, statistics"},
            {"job_title": "Machine Learning Engineer I", "role_category": "ml_engineer",
             "skills_str": "python, machine learning, tensorflow, scikit-learn, statistics"},
            {"job_title": "Machine Learning Engineer II", "role_category": "ml_engineer",
             "skills_str": "python, machine learning, tensorflow, deep learning"},
            {"job_title": "Machine Learning Engineer III", "role_category": "ml_engineer",
             "skills_str": "python, machine learning, scikit-learn"},
            {"job_title": "Frontend Developer I", "role_category": "frontend_developer",
             "skills_str": "javascript, html, css, react"},
            {"job_title": "Frontend Developer II", "role_category": "frontend_developer",
             "skills_str": "javascript, html, css"},
        ])

    if "skills_str" not in df.columns:
        raise ValueError("Expected a 'skills_str' column in the dataset")
    if "role_category" not in df.columns:
        df["role_category"] = "general"
    df["role_category"] = df["role_category"].fillna("general")

    df["skills"] = df["skills_str"].apply(parse_skill_list)
    return df


jobs_df = load_job_dataset(DATA_PATH)
print(f"{len(jobs_df)} postings across {jobs_df['role_category'].nunique()} role categories")
jobs_df.head()
# Out:
# Loaded 1172 job postings from 'C:\ProjectsVScode\Capstone\jobs_dataset_skills_final.csv'
# 1172 postings across 19 role categories
#                              job_title                company location  \
# 0                    Backend Developer     Spatial Front, Inc   Remote
# 1  Backend Developer (Streaming Focus)  Network Designs, Inc.   Remote
# 2               Java Backend Developer              Openkyber   Remote
# 3         Software Developer (backend)          Ennoble First   Remote
# 4      Software Engineer III - Backend                Walmart   Remote
#
#   is_remote      role_category seniority_level is_aggregator  \
# 0       yes  backend_developer             NaN            no
# 1       yes  backend_developer             NaN            no
# 2       yes  backend_developer             NaN            no
# 3       yes  backend_developer             NaN            no
# 4       yes  backend_developer             NaN            no
#
#                                           skills_str  \
# 0  python, java, sql, node.js, aws, docker, kuber...
# 1                 java, aws, docker, kubernetes, git
# 2                                          java, sql
# 3                           python, java, css, linux
# 4            python, java, c++, sql, aws, excel, git
#
#                                               skills
# 0  [aws, docker, java, kubernetes, node js, pytho...
# 1               [aws, docker, git, java, kubernetes]
# 2                                        [java, sql]
# 3                         [css, java, linux, python]
# 4            [aws, c, excel, git, java, python, sql]

# %% [markdown]
# ## 4. Domain Model
# Skill and JobRole classes used by the rule engine.

# %%
@dataclass
class JobRole:
    role_id: str
    title: str
    required_skills: List[str]
    preferred_skills: List[str] = field(default_factory=list)
    recommendation_text: str = ""
    postings_analyzed: int = 0

    def match_against(self, user_skills: set) -> Dict[str, Any]:
        req = set(self.required_skills)
        pref = set(self.preferred_skills)

        req_missing = sorted(req - user_skills)
        pref_missing = sorted(pref - user_skills)
        req_matched = len(req) - len(req_missing)
        pref_matched = len(pref) - len(pref_missing)

        # required skills weighted double, preferred skills weighted single
        total_weight = (len(req) * 2) + len(pref)
        earned_weight = (req_matched * 2) + pref_matched
        match_score = round(earned_weight / total_weight, 3) if total_weight else 0.0

        return {
            "role": self.title,
            "match_score": match_score,
            "required_matched": req_matched,
            "required_total": len(req),
            "preferred_matched": pref_matched,
            "preferred_total": len(pref),
            "required_missing": req_missing,
            "preferred_missing": pref_missing,
            "recommendation": self.recommendation_text,
        }

print("JobRole class defined")
# Out:
# JobRole class defined

# %% [markdown]
# ## 5. Build Rule-Based Decision Engine
# Derive IF-THEN rules from the job dataset: a skill is REQUIRED if it appears in most postings for a role, PREFERRED if it appears less often.

# %%
class RuleEngine:
    def __init__(self, jobs_df: pd.DataFrame,
                 required_threshold: float = 0.5,
                 preferred_threshold: float = 0.2):
        self.required_threshold = required_threshold
        self.preferred_threshold = preferred_threshold
        self.roles: List[JobRole] = self._build_rules(jobs_df)

    def _build_rules(self, jobs_df: pd.DataFrame) -> List[JobRole]:
        roles = []
        for category, group in jobs_df.groupby("role_category"):
            n_postings = len(group)
            skill_counts: Dict[str, int] = {}
            for skills in group["skills"]:
                for s in skills:
                    skill_counts[s] = skill_counts.get(s, 0) + 1

            required, preferred = [], []
            for skill, count in skill_counts.items():
                freq = count / n_postings
                if freq >= self.required_threshold:
                    required.append(skill)
                elif freq >= self.preferred_threshold:
                    preferred.append(skill)

            if not required and not preferred:
                continue

            title = category.replace("_", " ").title()
            roles.append(JobRole(
                role_id=category,
                title=title,
                required_skills=sorted(required),
                preferred_skills=sorted(preferred),
                postings_analyzed=n_postings,
                recommendation_text=(
                    f"Derived from {n_postings} '{title}' postings \u2014 "
                    f"required: {', '.join(sorted(required)) or 'none identified'}; "
                    f"preferred: {', '.join(sorted(preferred)) or 'none identified'}."
                ),
            ))
        return roles

    def evaluate(self, user_skills: List[str]) -> Dict[str, Any]:
        user_set = {normalize_text(s) for s in user_skills}
        results = [role.match_against(user_set) for role in self.roles]
        results.sort(key=lambda r: (-r["match_score"], len(r["required_missing"])))
        return {"rules_evaluated": len(results), "rules": results}


rule_engine = RuleEngine(jobs_df)
print(f"Rule engine built {len(rule_engine.roles)} role rules from the dataset:")
for role in rule_engine.roles:
    print(f"  - {role.title}: required={role.required_skills} | preferred={role.preferred_skills}")
# Out:
# Rule engine built 19 role rules from the dataset:
#   - Ai Engineer: required=['aws', 'azure', 'excel', 'java', 'machine learning', 'python'] | preferred=['deep learning', 'docker', 'git', 'javascript', 'node js', 'react', 'tensorflow']
#   - Backend Developer: required=['aws', 'java', 'sql'] | preferred=['docker', 'excel', 'git', 'kubernetes', 'python']
#   - Cloud Engineer: required=['aws', 'azure'] | preferred=['docker', 'excel', 'git', 'kubernetes', 'python']
#   - Cybersecurity Analyst: required=['excel'] | preferred=['aws', 'git', 'linux']
#   - Data Analyst: required=['excel', 'sql'] | preferred=['aws', 'git', 'power bi', 'python', 'tableau']
#   - Data Engineer: required=['aws', 'azure', 'machine learning', 'python', 'sql'] | preferred=['excel', 'git', 'java', 'kubernetes', 'linux']
#   - Data Scientist: required=['aws', 'machine learning', 'python', 'sql'] | preferred=['excel', 'git', 'tensorflow']
#   - Devops Engineer: required=['aws', 'docker', 'excel', 'git', 'java', 'kubernetes', 'python', 'sql'] | preferred=['azure', 'javascript', 'linux']
#   - Frontend Developer: required=['angular', 'css', 'git', 'html', 'java', 'javascript', 'react'] | preferred=['aws', 'excel']
#   - Full Stack Developer: required=['angular', 'java', 'react', 'sql'] | preferred=['aws', 'azure', 'css', 'docker', 'excel', 'git', 'html', 'javascript', 'kubernetes', 'python']
#   - Machine Learning Engineer: required=['aws', 'machine learning', 'python'] | preferred=['azure', 'c', 'deep learning', 'excel', 'git', 'java', 'sql', 'tensorflow']
#   - Mlops Engineer: required=['aws', 'docker', 'git', 'kubernetes', 'machine learning', 'python'] | preferred=[]
#   - Network Engineer: required=['aws', 'azure', 'excel', 'python'] | preferred=[]
#   - Other: required=['excel'] | preferred=['aws', 'azure', 'git', 'python', 'sql']
#   - Platform Engineer: required=['aws', 'azure', 'git', 'kubernetes', 'linux', 'python'] | preferred=['docker']
#   - Security Analyst: required=['aws', 'excel'] | preferred=[]
#   - Software Engineer: required=['aws', 'git', 'java', 'python'] | preferred=['angular', 'c', 'css', 'excel', 'html', 'javascript', 'linux', 'react', 'sql']
#   - Systems Engineer: required=['aws', 'git', 'python'] | preferred=['azure', 'docker', 'kubernetes', 'linux', 'machine learning']
#   - Web Developer: required=['css', 'html', 'java', 'javascript', 'react'] | preferred=[]

# %%
user_profile = {
    "name": "Alice",
    "skills": ["Python", "SQL", "Data Visualization", "Communication"],
}

rule_output = rule_engine.evaluate(user_profile["skills"])
print(json.dumps(rule_output, indent=2))
# Out:
# {
#   "rules_evaluated": 19,
#   "rules": [
#     {
#       "role": "Data Scientist",
#       "match_score": 0.364,
#       "required_matched": 2,
#       "required_total": 4,
#       "preferred_matched": 0,
#       "preferred_total": 3,
#       "required_missing": [
#         "aws",
#         "machine learning"
#       ],
#       "preferred_missing": [
#         "excel",
#         "git",
#         "tensorflow"
#       ],
#       "recommendation": "Derived from 164 'Data Scientist' postings \u2014 required: aws, machine learning, python, sql; preferred: excel, git, tensorflow."
#     },
#     {
#       "role": "Data Analyst",
#       "match_score": 0.333,
#       "required_matched": 1,
#       "required_total": 2,
#       "preferred_matched": 1,
#       "preferred_total": 5,
#       "required_missing": [
#         "excel"
#       ],
#       "preferred_missing": [
#         "aws",
#         "git",
#         "power bi",
#         "tableau"
#       ],
#       "recommendation": "Derived from 76 'Data Analyst' postings \u2014 required: excel, sql; preferred: aws, git, power bi, python, tableau."
#     },
#     {
#       "role": "Other",
#       "match_score": 0.286,
#       "required_matched": 0,
#       "required_total": 1,
#       "preferred_matched": 2,
#       "preferred_total": 5,
#       "required_missing": [
#         "excel"
#       ],
#       "preferred_missing": [
#         "aws",
#         "azure",
#         "git"
#       ],
#       "recommendation": "Derived from 109 'Other' postings \u2014 required: excel; preferred: aws, azure, git, python, sql."
#     },
#     {
#       "role": "Backend Developer",
#       "match_score": 0.273,
#       "required_matched": 1,
#       "required_total": 3,
#       "preferred_matched": 1,
#       "preferred_total": 5,
#       "required_missing": [
#         "aws",
#         "java"
#       ],
#       "preferred_missing": [
#         "docker",
#         "excel",
#         "git",
#         "kubernetes"
#       ],
#       "recommendation": "Derived from 150 'Backend Developer' postings \u2014 required: aws, java, sql; preferred: docker, excel, git, kubernetes, python."
#     },
#     {
#       "role": "Data Engineer",
#       "match_score": 0.267,
#       "required_matched": 2,
#       "required_total": 5,
#       "preferred_matched": 0,
#       "preferred_total": 5,
#       "required_missing": [
#         "aws",
#         "azure",
#         "machine learning"
#       ],
#       "preferred_missing": [
#         "excel",
#         "git",
#         "java",
#         "kubernetes",
#         "linux"
#       ],
#       "recommendation": "Derived from 5 'Data Engineer' postings \u2014 required: aws, azure, machine learning, python, sql; preferred: excel, git, java, kubernetes, linux."
#     },
#     {
#       "role": "Network Engineer",
#       "match_score": 0.25,
#       "required_matched": 1,
#       "required_total": 4,
#       "preferred_matched": 0,
#       "preferred_total": 0,
#       "required_missing": [
#         "aws",
#         "azure",
#         "excel"
#       ],
#       "preferred_missing": [],
#       "recommendation": "Derived from 2 'Network Engineer' postings \u2014 required: aws, azure, excel, python; preferred: none identified."
#     },
#     {
#       "role": "Machine Learning Engineer",
#       "match_score": 0.214,
#       "required_matched": 1,
#       "required_total": 3,
#       "preferred_matched": 1,
#       "preferred_total": 8,
#       "required_missing": [
#         "aws",
#         "machine learning"
#       ],
#       "preferred_missing": [
#         "azure",
#         "c",
#         "deep learning",
#         "excel",
#         "git",
#         "java",
#         "tensorflow"
#       ],
#       "recommendation": "Derived from 150 'Machine Learning Engineer' postings \u2014 required: aws, machine learning, python; preferred: azure, c, deep learning, excel, git, java, sql, tensorflow."
#     },
#     {
#       "role": "Devops Engineer",
#       "match_score": 0.211,
#       "required_matched": 2,
#       "required_total": 8,
#       "preferred_matched": 0,
#       "preferred_total": 3,
#       "required_missing": [
#         "aws",
#         "docker",
#         "excel",
#         "git",
#         "java",
#         "kubernetes"
#       ],
#       "preferred_missing": [
#         "azure",
#         "javascript",
#         "linux"
#       ],
#       "recommendation": "Derived from 7 'Devops Engineer' postings \u2014 required: aws, docker, excel, git, java, kubernetes, python, sql; preferred: azure, javascript, linux."
#     },
#     {
#       "role": "Systems Engineer",
#       "match_score": 0.182,
#       "required_matched": 1,
#       "required_total": 3,
#       "preferred_matched": 0,
#       "preferred_total": 5,
#       "required_missing": [
#         "aws",
#         "git"
#       ],
#       "preferred_missing": [
#         "azure",
#         "docker",
#         "kubernetes",
#         "linux",
#         "machine learning"
#       ],
#       "recommendation": "Derived from 3 'Systems Engineer' postings \u2014 required: aws, git, python; preferred: azure, docker, kubernetes, linux, machine learning."
#     },
#     {
#       "role": "Software Engineer",
#       "match_score": 0.176,
#       "required_matched": 1,
#       "required_total": 4,
#       "preferred_matched": 1,
#       "preferred_total": 9,
#       "required_missing": [
#         "aws",
#         "git",
#         "java"
#       ],
#       "preferred_missing": [
#         "angular",
#         "c",
#         "css",
#         "excel",
#         "html",
#         "javascript",
#         "linux",
#         "react"
#       ],
#       "recommendation": "Derived from 147 'Software Engineer' postings \u2014 required: aws, git, java, python; preferred: angular, c, css, excel, html, javascript, linux, react, sql."
#     },
#     {
#       "role": "Full Stack Developer",
#       "match_score": 0.167,
#       "required_matched": 1,
#       "required_total": 4,
#       "preferred_matched": 1,
#       "preferred_total": 10,
#       "required_missing": [
#         "angular",
#         "java",
#         "react"
#       ],
#       "preferred_missing": [
#         "aws",
#         "azure",
#         "css",
#         "docker",
#         "excel",
#         "git",
#         "html",
#         "javascript",
#         "kubernetes"
#       ],
#       "recommendation": "Derived from 16 'Full Stack Developer' postings \u2014 required: angular, java, react, sql; preferred: aws, azure, css, docker, excel, git, html, javascript, kubernetes, python."
#     },
#     {
#       "role": "Mlops Engineer",
#       "match_score": 0.167,
#       "required_matched": 1,
#       "required_total": 6,
#       "preferred_matched": 0,
#       "preferred_total": 0,
#       "required_missing": [
#         "aws",
#         "docker",
#         "git",
#         "kubernetes",
#         "machine learning"
#       ],
#       "preferred_missing": [],
#       "recommendation": "Derived from 2 'Mlops Engineer' postings \u2014 required: aws, docker, git, kubernetes, machine learning, python; preferred: none identified."
#     },
#     {
#       "role": "Platform Engineer",
#       "match_score": 0.154,
#       "required_matched": 1,
#       "required_total": 6,
#       "preferred_matched": 0,
#       "preferred_total": 1,
#       "required_missing": [
#         "aws",
#         "azure",
#         "git",
#         "kubernetes",
#         "linux"
#       ],
#       "preferred_missing": [
#         "docker"
#       ],
#       "recommendation": "Derived from 4 'Platform Engineer' postings \u2014 required: aws, azure, git, kubernetes, linux, python; preferred: docker."
#     },
#     {
#       "role": "Cloud Engineer",
#       "match_score": 0.111,
#       "required_matched": 0,
#       "required_total": 2,
#       "preferred_matched": 1,
#       "preferred_total": 5,
#       "required_missing": [
#         "aws",
#         "azure"
#       ],
#       "preferred_missing": [
#         "docker",
#         "excel",
#         "git",
#         "kubernetes"
#       ],
#       "recommendation": "Derived from 102 'Cloud Engineer' postings \u2014 required: aws, azure; preferred: docker, excel, git, kubernetes, python."
#     },
#     {
#       "role": "Ai Engineer",
#       "match_score": 0.105,
#       "required_matched": 1,
#       "required_total": 6,
#       "preferred_matched": 0,
#       "preferred_total": 7,
#       "required_missing": [
#         "aws",
#         "azure",
#         "excel",
#         "java",
#         "machine learning"
#       ],
#       "preferred_missing": [
#         "deep learning",
#         "docker",
#         "git",
#         "javascript",
#         "node js",
#         "react",
#         "tensorflow"
#       ],
#       "recommendation": "Derived from 8 'Ai Engineer' postings \u2014 required: aws, azure, excel, java, machine learning, python; preferred: deep learning, docker, git, javascript, node js, react, tensorflow."
#     },
#     {
#       "role": "Cybersecurity Analyst",
#       "match_score": 0.0,
#       "required_matched": 0,
#       "required_total": 1,
#       "preferred_matched": 0,
#       "preferred_total": 3,
#       "required_missing": [
#         "excel"
#       ],
#       "preferred_missing": [
#         "aws",
#         "git",
#         "linux"
#       ],
#       "recommendation": "Derived from 100 'Cybersecurity Analyst' postings \u2014 required: excel; preferred: aws, git, linux."
#     },
#     {
#       "role": "Security Analyst",
#       "match_score": 0.0,
#       "required_matched": 0,
#       "required_total": 2,
#       "preferred_matched": 0,
#       "preferred_total": 0,
#       "required_missing": [
#         "aws",
#         "excel"
#       ],
#       "preferred_missing": [],
#       "recommendation": "Derived from 7 'Security Analyst' postings \u2014 required: aws, excel; preferred: none identified."
#     },
#     {
#       "role": "Web Developer",
#       "match_score": 0.0,
#       "required_matched": 0,
#       "required_total": 5,
#       "preferred_matched": 0,
#       "preferred_total": 0,
#       "required_missing": [
#         "css",
#         "html",
#         "java",
#         "javascript",
#         "react"
#       ],
#       "preferred_missing": [],
#       "recommendation": "Derived from 4 'Web Developer' postings \u2014 required: css, html, java, javascript, react; preferred: none identified."
#     },
#     {
#       "role": "Frontend Developer",
#       "match_score": 0.0,
#       "required_matched": 0,
#       "required_total": 7,
#       "preferred_matched": 0,
#       "preferred_total": 2,
#       "required_missing": [
#         "angular",
#         "css",
#         "git",
#         "html",
#         "java",
#         "javascript",
#         "react"
#       ],
#       "preferred_missing": [
#         "aws",
#         "excel"
#       ],
#       "recommendation": "Derived from 116 'Frontend Developer' postings \u2014 required: angular, css, git, html, java, javascript, react; preferred: aws, excel."
#     }
#   ]
# }

# %% [markdown]
# ## 6. Generate DAG-Based Learning Path
# Model skill dependencies as a directed acyclic graph and use topological sort to produce an ordered learning path for missing skills.

# %%
class LearningPathGenerator:
    DEFAULT_DEPENDENCIES: Dict[str, List[str]] = {
        "data structures": ["python basics"],
        "algorithms": ["data structures"],
        "sql": ["data structures"],
        "web frameworks": ["sql"],
        "statistics": ["python basics"],
        "excel": ["python basics"],
        "tensorflow": ["python basics"],
        "scikit-learn": ["python basics"],
        "machine learning": ["python basics", "statistics"],
        "deep learning": ["machine learning", "tensorflow"],
        "data visualization": ["python basics", "excel"],
        "docker": ["python basics"],
        "aws": ["docker"],
        "kubernetes": ["docker"],
        "power bi": ["excel"],
        "tableau": ["excel"],
        "react": ["javascript"],
    }

    def __init__(self, dependencies: Optional[Dict[str, List[str]]] = None):
        self.dependencies = dependencies or self.DEFAULT_DEPENDENCIES
        self.graph = self._build_graph(self.dependencies)

    @staticmethod
    def _build_graph(dependencies: Dict[str, List[str]]) -> nx.DiGraph:
        graph = nx.DiGraph()
        for skill, prereqs in dependencies.items():
            graph.add_node(skill)
            for prereq in prereqs:
                graph.add_edge(prereq, skill)
        if not nx.is_directed_acyclic_graph(graph):
            raise ValueError("Skill dependency graph must be acyclic.")
        return graph

    def generate_path(self, user_skills: List[str],
                       target_skills: Optional[List[str]] = None) -> List[str]:
        known = {normalize_text(s) for s in user_skills}

        if target_skills is not None:
            missing = [normalize_text(s) for s in target_skills if normalize_text(s) not in known]
        else:
            missing = [n for n in self.graph.nodes if n not in known]

        in_graph = [m for m in missing if m in self.graph.nodes]
        not_in_graph = [m for m in missing if m not in self.graph.nodes]
        if not_in_graph:
            print(f"No prerequisite mapping for: {not_in_graph}")

        if not in_graph:
            return []

        required_prereqs = set()
        for skill in in_graph:
            required_prereqs.update(
                p for p in nx.ancestors(self.graph, skill) if normalize_text(p) not in known
            )

        subgraph_nodes = required_prereqs.union(in_graph)
        subgraph = self.graph.subgraph(subgraph_nodes).copy()
        ordered = list(nx.topological_sort(subgraph))
        return [skill for skill in ordered if normalize_text(skill) not in known]


path_generator = LearningPathGenerator()
print(f"DAG built with {path_generator.graph.number_of_nodes()} skill nodes and "
      f"{path_generator.graph.number_of_edges()} prerequisite edges.")
# Out:
# DAG built with 19 skill nodes and 20 prerequisite edges.

# %%
learning_path: List[str] = []
if rule_output["rules"]:
    top_role = rule_output["rules"][0]
    missing_for_top_role = top_role["required_missing"] + top_role["preferred_missing"]
    learning_path = path_generator.generate_path(user_profile["skills"], missing_for_top_role)
    role_name = top_role["role"]
    role_score = top_role["match_score"]
    print(f"Top matched role: '{role_name}' (score={role_score})")
    if learning_path:
        print(f"Ordered learning path: {learning_path}")
    else:
        print("Ordered learning path: No dependency-mapped skills missing for this role.")
else:
    print("[RULE ENGINE] No roles could be evaluated - check the dataset.")
# Out:
# No prerequisite mapping for: ['git']
# Top matched role: 'Data Scientist' (score=0.364)
# Ordered learning path: ['python basics', 'statistics', 'excel', 'tensorflow', 'docker', 'machine learning', 'aws']

# %% [markdown]
# ## 7. Persist Jobs and Rules to MongoDB
# Disabled by default (USE_MONGODB=False). Set the flag to True and install pymongo on the database machine to enable this.

# %%
class DatabaseManager:
    def __init__(self, uri: str = MONGO_URI, db_name: str = MONGO_DB_NAME):
        from pymongo import MongoClient
        self.client = MongoClient(uri, serverSelectionTimeoutMS=3000)
        self.db = self.client[db_name]
        self.jobs_collection = self.db["jobs"]
        self.users_collection = self.db["users"]
        self.rules_collection = self.db["rules"]

    def save_jobs(self, jobs_df: pd.DataFrame) -> None:
        self.jobs_collection.delete_many({})
        self.jobs_collection.insert_many(jobs_df.to_dict(orient="records"))

    def save_rules(self, rule_engine: "RuleEngine") -> None:
        self.rules_collection.delete_many({})
        docs = [role.__dict__ for role in rule_engine.roles]
        self.rules_collection.insert_many(docs)

    def save_user_result(self, user_profile: Dict[str, Any],
                          rule_output: Dict[str, Any],
                          learning_path: List[str]) -> None:
        doc = {
            "name": user_profile.get("name"),
            "skills": user_profile.get("skills"),
            "rule_recommendations": rule_output,
            "learning_path": learning_path,
        }
        self.users_collection.delete_many({"name": doc["name"]})
        self.users_collection.insert_one(doc)

    def fetch_rules(self) -> List[Dict[str, Any]]:
        return list(self.rules_collection.find({}, {"_id": 0}))


if USE_MONGODB:
    db_manager = DatabaseManager()
    db_manager.save_jobs(jobs_df)
    db_manager.save_rules(rule_engine)
    db_manager.save_user_result(user_profile, rule_output, learning_path)
    print("[MongoDB] Persistence complete.")
else:
    print("[MongoDB] Skipped (USE_MONGODB=False). Flip the flag in the config "
          "cell on the database machine to enable persistence.")
# Out:
# [MongoDB] Skipped (USE_MONGODB=False). Flip the flag in the config cell on the database machine to enable persistence.

# %% [markdown]
# ## 8. Expose Flask Endpoints for Recommendations
# Disabled by default (RUN_FLASK_APP=False). Set the flag to True and install flask on the deployment machine to enable this.

# %%
def create_app(rule_engine: "RuleEngine", path_generator: "LearningPathGenerator"):
    from flask import Flask, request, jsonify

    app = Flask(__name__)

    @app.route("/recommend", methods=["POST"])
    def recommend():
        payload = request.json or {}
        user_skills = payload.get("skills", [])

        rule_output = rule_engine.evaluate(user_skills)
        missing_for_top_role = []
        if rule_output["rules"]:
            top_role = rule_output["rules"][0]
            missing_for_top_role = top_role["required_missing"] + top_role["preferred_missing"]

        path = path_generator.generate_path(user_skills, missing_for_top_role)

        return jsonify({
            "rule_recommendations": rule_output,
            "learning_path": path,
            "input_skills": user_skills,
        })

    @app.route("/rules", methods=["GET"])
    def list_rules():
        return jsonify({"rules": [role.__dict__ for role in rule_engine.roles]})

    return app


if RUN_FLASK_APP:
    app = create_app(rule_engine, path_generator)
    print("[Flask] Starting server on http://0.0.0.0:5001 ...")
    app.run(host="0.0.0.0", port=5001, debug=True)
else:
    print("[Flask] Skipped (RUN_FLASK_APP=False). Flip the flag in the config "
          "cell on the deployment machine to start the API server.")
# Out:
# [Flask] Skipped (RUN_FLASK_APP=False). Flip the flag in the config cell on the deployment machine to start the API server.

# %% [markdown]
# ## 9. Demonstrate End-to-End Pipeline
# Run a sample user through the rule engine and DAG learning path to show the complete workflow.

# %%
summary = {
    "user": user_profile,
    "top_recommendations": rule_output["rules"][:3],
    "learning_path_for_top_match": learning_path,
}
print(json.dumps(summary, indent=2))
# Out:
# {
#   "user": {
#     "name": "Alice",
#     "skills": [
#       "Python",
#       "SQL",
#       "Data Visualization",
#       "Communication"
#     ]
#   },
#   "top_recommendations": [
#     {
#       "role": "Data Scientist",
#       "match_score": 0.364,
#       "required_matched": 2,
#       "required_total": 4,
#       "preferred_matched": 0,
#       "preferred_total": 3,
#       "required_missing": [
#         "aws",
#         "machine learning"
#       ],
#       "preferred_missing": [
#         "excel",
#         "git",
#         "tensorflow"
#       ],
#       "recommendation": "Derived from 164 'Data Scientist' postings \u2014 required: aws, machine learning, python, sql; preferred: excel, git, tensorflow."
#     },
#     {
#       "role": "Data Analyst",
#       "match_score": 0.333,
#       "required_matched": 1,
#       "required_total": 2,
#       "preferred_matched": 1,
#       "preferred_total": 5,
#       "required_missing": [
#         "excel"
#       ],
#       "preferred_missing": [
#         "aws",
#         "git",
#         "power bi",
#         "tableau"
#       ],
#       "recommendation": "Derived from 76 'Data Analyst' postings \u2014 required: excel, sql; preferred: aws, git, power bi, python, tableau."
#     },
#     {
#       "role": "Other",
#       "match_score": 0.286,
#       "required_matched": 0,
#       "required_total": 1,
#       "preferred_matched": 2,
#       "preferred_total": 5,
#       "required_missing": [
#         "excel"
#       ],
#       "preferred_missing": [
#         "aws",
#         "azure",
#         "git"
#       ],
#       "recommendation": "Derived from 109 'Other' postings \u2014 required: excel; preferred: aws, azure, git, python, sql."
#     }
#   ],
#   "learning_path_for_top_match": [
#     "python basics",
#     "statistics",
#     "excel",
#     "tensorflow",
#     "docker",
#     "machine learning",
#     "aws"
#   ]
# }
